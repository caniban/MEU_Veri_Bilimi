# %% [markdown]
# # T.C. MERSİN ÜNİVERSİTESİ
# ## Mühendislik Fakültesi – Harita Mühendisliği Bölümü
# ### 2025–2026 Akademik Yılı Güz Dönemi
#
# ---
#
# # 1603006 Programlama Dersi – Ara Sınavı
# **Tarih:** 11 Kasım 2025
#
# ---
#
# ## Dosya Adı Formatı
# `isim_soyisim_numara_arasinav.ipynb`
#
# ---
#
# ## E-posta Gönderimi
# Sınav süresi bitmeden dosyanızı aşağıdaki adrese gönderiniz:
# **E-posta:** `caniban@mersin.edu.tr`
#
# ---
#
# ## Önemli Uyarılar
# - Bulut bağlantısı (Google Drive, OneDrive vb.) kabul edilmez.
# - Dosyanızı Colab’tan indirip doğrudan e-posta eki olarak gönderiniz.
# - Süre: 75 dakika
# - Üretken yapay zeka kullanımı kesinlikle yasaktır.
#
# ---
#
# ## İlgili Öğrenme Çıktıları
# 1. **Ö.Ç. 1:** Python programlama dilinin temel çalışma anlayışını kavrar (Soru 1, Soru 2)
# 2. **Ö.Ç. 2:** Veri türleri arasındaki farkları ve farklı veri dosyalarını Python’da nasıl işleyebileceğini öğrenir (Soru 3, Soru 4, Soru 5)

# %% [markdown]
# ## 1. Soru
#
# Kullanıcıdan üç kenar uzunluğu (**a**, **b**, **c**) isteyiniz.
# Girilen değerlere göre:
#
# 1. Bu kenarlarla **bir üçgen oluşturulup oluşturulamayacağını** kontrol eden,
# 2. Eğer oluşturulabiliyorsa **üçgenin türünü** belirleyen
#    - Eşkenar
#    - İkizkenar
#    - Çeşitkenar
# 3. Ve son olarak **alanını Heron formülüyle** hesaplayan
# bir **Python programı** yazınız.
#
# ---
#
# ### 🔹 Heron Formülü:
# $
# Alan = \sqrt{s \times (s - a) \times (s - b) \times (s - c)}
# $
# burada:
# $
# s = \frac{a + b + c}{2}
# $
#
# ---

# %% [markdown]
# ## 2. Soru
#
# Bir laboratuvarda 10 adet ölçüm yapılmıştır. Her ölçümün bir güvenilirlik katsayısı (ağırlığı) vardır.
# Aşağıdaki verileri kullanarak hesaplama yapınız:
#
# | Ölçüm No | Ölçüm (°C) | Ağırlık |
# |:--------:|:-----------:|:-------:|
# | 1  | 19.8 | 0.9 |
# | 2  | 20.1 | 1.0 |
# | 3  | 19.9 | 0.7 |
# | 4  | 20.3 | 0.6 |
# | 5  | 19.7 | 1.0 |
# | 6  | 20.0 | 0.8 |
# | 7  | 20.4 | 0.5 |
# | 8  | 19.6 | 0.9 |
# | 9  | 19.8 | 1.0 |
# | 10 | 20.2 | 0.6 |
#
# ---
#
# ### Görevler:
#
# 1. Ölçümler ve ağırlıkları NumPy dizisi olarak tanımlayınız.
# 2. Ağırlıklı ortalamayı hesaplayınız:
#
# $
# \bar{x}_a = \frac{\sum (w_i \cdot x_i)}{\sum w_i}
# $
#
# 3. Ağırlıklı standart sapmayı hesaplayınız:
#
# $
# \sigma_w = \sqrt{\frac{\sum (w_i \cdot (x_i - \bar{x}_a)^2)}{\sum w_i}}
# $
#
# 4. Sonuçları ekrana yazdırınız.
#
# ###  Kullanabileceğiniz NumPy Fonksiyonları:
# `np.array`, `np.sum`, `np.multiply`, `np.sqrt`, `np.power`
#
# ###  Not:
# - Döngü (`for` / `while`) kullanmayınız.
# - Tüm hesaplamalar NumPy matris/vektör işlemleriyle yapılmalıdır.

# %% [markdown]
# ## 3. Soru
# Aşağıdaki cümle üzerinde işlem yapınız:
# `Python programlama dili, veri analizi ve makine öğrenmesi için çok uygundur.`
#
# ---
#
# #### Görevler:
# 1. Cümlenin **toplam karakter sayısını** bulunuz.
# 2. Cümledeki tüm kelimeleri küçük harfe çevirip bir listeye atınız (`split` kullanınız).
# 3. Listenin içinden **5 veya daha uzun harfli kelimeleri** yeni bir listeye alın.
# 4. Cümlede kaç kez `'ve'` hecesinin geçtiğini sayınız (`count` metodunu kullanınız).
# 5. Yeni oluşturduğunuz kelime listesini alfabetik sıraya göre ekrana yazdırınız.

# %% [markdown]
# ## 4. Soru
#
# Bir sınıfta 15 öğrenciye ait sınav notları rastgele üretilmiştir.
# Öğrencilerin başarı durumlarını belirlemek ve istatistiksel analiz yapmak için bir Python programı yazınız.
#
# ---
#
# ### Görevler:
#
# 1. `numpy` kullanarak 15 öğrencinin sınav notlarını **0 ile 100 arasında rastgele** oluşturunuz.
# 2. `for` döngüsü kullanarak her bir notu kontrol ediniz:
#    - Not **50 ve üstü** ise `"Geçti"`
#    - Not **50 altı** ise `"Kaldı"`
#    olarak bir listeye ekleyiniz.
#
# 3. `Geçti` ve `Kaldı` sayısını `if` koşulu kullanarak hesaplayınız.
#
# 4. NumPy fonksiyonları kullanarak:
#    - Ortalama notu
#    - En yüksek notu
#    - En düşük notu
#    - Standart sapmayı
#    hesaplayınız.
